# %%
import os
import random
import pandas as pd
import numpy as np
from shutil import copyfile

data_dir='/data/stilo/catalog_full'
print(len(os.listdir(data_dir+'/skirt/')))
print(len(os.listdir(data_dir+'/jeans/')))
print(len(os.listdir(data_dir+'/dress/')))
# Out:
# 2424
# 4747
# 14645

# %%
print(os.listdir(data_dir))

# %%
classes=os.listdir(data_dir)

# %%
classes.remove('stuff')

# %%
classes
# Out:
# ['skirt',
#  'stuff',
#  'jacket',
#  'sweatshirt',
#  'footwear',
#  'sweater',
#  'shirt',
#  'jeans',
#  'bag',
#  'pants',
#  'dress',
#  'suit',
#  'coat',
#  't-shirt',
#  'headwear',
#  'glasses',
#  'jewelry']

# %%
source_path=[f'/data/stilo/catalog_full/{a}' for a in classes]
print(source_path)
# Out:
# ['/data/stilo/catalog_full/skirt', '/data/stilo/catalog_full/jacket', '/data/stilo/catalog_full/sweatshirt', '/data/stilo/catalog_full/footwear', '/data/stilo/catalog_full/sweater', '/data/stilo/catalog_full/shirt', '/data/stilo/catalog_full/jeans', '/data/stilo/catalog_full/bag', '/data/stilo/catalog_full/pants', '/data/stilo/catalog_full/dress', '/data/stilo/catalog_full/suit', '/data/stilo/catalog_full/coat', '/data/stilo/catalog_full/t-shirt', '/data/stilo/catalog_full/headwear', '/data/stilo/catalog_full/glasses', '/data/stilo/catalog_full/jewelry']

# %%
classes_dir=[f'{a}_dir' for a in classes]
classes_dir
# Out:
# ['skirt_dir',
#  'jacket_dir',
#  'sweatshirt_dir',
#  'footwear_dir',
#  'sweater_dir',
#  'shirt_dir',
#  'jeans_dir',
#  'bag_dir',
#  'pants_dir',
#  'dress_dir',
#  'suit_dir',
#  'coat_dir',
#  't-shirt_dir',
#  'headwear_dir',
#  'glasses_dir',
#  'jewelry_dir']

# %%
for cl_dir,cl_path in zip(classes_dir,source_path):
    print(cl_dir,': ',len(os.listdir(cl_path)))
# Out:
# skirt_dir :  2424
# jacket_dir :  4587
# sweatshirt_dir :  2687
# footwear_dir :  6950
# sweater_dir :  1855
# shirt_dir :  5020
# jeans_dir :  4747
# bag_dir :  986
# pants_dir :  7272
# dress_dir :  14645
# suit_dir :  5155
# coat_dir :  295
# t-shirt_dir :  15222
# headwear_dir :  338
# glasses_dir :  812
# jewelry_dir :  1885

# %%
# !pwd
# Out:
# /home/ach/stilo

# %%
try:
    os.mkdir('/home/ach/stilo/training')
    os.mkdir('/home/ach/stilo/validation')
    os.mkdir('/home/ach/stilo/testing')
except OSError:
    pass

# %%
TRAINING_PATH='/home/ach/stilo/training'
VALIDATION_PATH='/home/ach/stilo/validation'
training_dir_path=[f'/home/ach/stilo/training/{a}' for a in classes]
print('\n',training_dir_path)
validation_dir_path=[f'/home/ach/stilo/validation/{a}' for a in classes]
print('\n',validation_dir_path)
testing_dir_path=[f'/home/ach/stilo/testing/{a}' for a in classes]
print('\n',testing_dir_path)
# Out:
#  ['/home/ach/stilo/training/skirt', '/home/ach/stilo/training/jacket', '/home/ach/stilo/training/sweatshirt', '/home/ach/stilo/training/footwear', '/home/ach/stilo/training/sweater', '/home/ach/stilo/training/shirt', '/home/ach/stilo/training/jeans', '/home/ach/stilo/training/bag', '/home/ach/stilo/training/pants', '/home/ach/stilo/training/dress', '/home/ach/stilo/training/suit', '/home/ach/stilo/training/coat', '/home/ach/stilo/training/t-shirt', '/home/ach/stilo/training/headwear', '/home/ach/stilo/training/glasses', '/home/ach/stilo/training/jewelry']
#
#  ['/home/ach/stilo/validation/skirt', '/home/ach/stilo/validation/jacket', '/home/ach/stilo/validation/sweatshirt', '/home/ach/stilo/validation/footwear', '/home/ach/stilo/validation/sweater', '/home/ach/stilo/validation/shirt', '/home/ach/stilo/validation/jeans', '/home/ach/stilo/validation/bag', '/home/ach/stilo/validation/pants', '/home/ach/stilo/validation/dress', '/home/ach/stilo/validation/suit', '/home/ach/stilo/validation/coat', '/home/ach/stilo/validation/t-shirt', '/home/ach/stilo/validation/headwear', '/home/ach/stilo/validation/glasses', '/home/ach/stilo/validation/jewelry']
#
#  ['/home/ach/stilo/testing/skirt', '/home/ach/stilo/testing/jacket', '/home/ach/stilo/testing/sweatshirt', '/home/ach/stilo/testing/footwear', '/home/ach/stilo/testing/sweater', '/home/ach/stilo/testing/shirt', '/home/ach/stilo/testing/jeans', '/home/ach/stilo/testing/bag', '/home/ach/stilo/testing/pants', '/home/ach/stilo/testing/dress', '/home/ach/stilo/testing/suit', '/home/ach/stilo/testing/coat', '/home/ach/stilo/testing/t-shirt', '/home/ach/stilo/testing/headwear', '/home/ach/stilo/testing/glasses', '/home/ach/stilo/testing/jewelry']

# %%
for train_dir_path in training_dir_path:
    try:
        os.mkdir(train_dir_path)
    except OSError:
        pass

# %%
for val_dir_path in validation_dir_path:
    try:
        os.mkdir(val_dir_path)
    except OSError:
        pass

# %%
for test_dir_path in testing_dir_path:
    try:
        os.mkdir(test_dir_path)
    except OSError:
        pass

# %%
def split_data(SOURCE, TRAINING, VALIDATION, TESTING, SPLIT_SIZE):
    files = []
    print('Split Data')
    for filename in os.listdir(SOURCE):
        file = SOURCE +'/'+ filename
        if os.path.getsize(file) > 0:
            files.append(filename)
        else:
            print(filename + " is zero length, so ignoring.")

    training_length = int( len(files)* SPLIT_SIZE)
    validation_length = int(len(files) * 0.10)
    testing_length = int(len(files) - training_length - validation_length)
    
    print('SOURCE: ',SOURCE, '\n TRAINING', TRAINING, '\n VALIDATION',VALIDATION, '\n ',len(files))
    print('training_length:',training_length)
    print('validation_length:',validation_length)
    print('testing_length:',testing_length)
    
    shuffled_set = random.sample(files, len(files))
    training_set = shuffled_set[0:training_length]
    validation_set = shuffled_set[training_length:(training_length+validation_length)]
    testing_set=shuffled_set[:testing_length]

    print(len(training_set))
    print(len(validation_set))
    print(len(testing_set))
    
    for filename in training_set:
        this_file = SOURCE +'/'+ filename
        destination = TRAINING +'/'+ filename
        copyfile(this_file, destination)
    

    for filename in validation_set:
        this_file = SOURCE +'/'+ filename
        destination = VALIDATION+'/' + filename
        copyfile(this_file, destination)
        
    for filename in validation_set:
        this_file = SOURCE +'/'+ filename
        destination = TESTING+'/' + filename
        copyfile(this_file, destination)

# %%
split_size = .85
for source,train_dir_path,val_dir_path,test_dir_path in zip(source_path,\
                                training_dir_path,validation_dir_path, testing_dir_path):
    #print('source: ',source,'\n', train_dir_path,'\n',val_dir_path,'\n')
    split_data(source,train_dir_path,val_dir_path,test_dir_path, split_size)
    print('Splitting \n')
# Out:
# Split Data
# SOURCE:  /data/stilo/catalog_full/skirt
#  TRAINING /home/ach/stilo/training/skirt
#  VALIDATION /home/ach/stilo/validation/skirt
#   2424
# training_length: 2060
# validation_length: 242
# testing_length: 122
# 2060
# 242
# 122
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/jacket
#  TRAINING /home/ach/stilo/training/jacket
#  VALIDATION /home/ach/stilo/validation/jacket
#   4587
# training_length: 3898
# validation_length: 458
# testing_length: 231
# 3898
# 458
# 231
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/sweatshirt
#  TRAINING /home/ach/stilo/training/sweatshirt
#  VALIDATION /home/ach/stilo/validation/sweatshirt
#   2687
# training_length: 2283
# validation_length: 268
# testing_length: 136
# 2283
# 268
# 136
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/footwear
#  TRAINING /home/ach/stilo/training/footwear
#  VALIDATION /home/ach/stilo/validation/footwear
#   6950
# training_length: 5907
# validation_length: 695
# testing_length: 348
# 5907
# 695
# 348
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/sweater
#  TRAINING /home/ach/stilo/training/sweater
#  VALIDATION /home/ach/stilo/validation/sweater
#   1855
# training_length: 1576
# validation_length: 185
# testing_length: 94
# 1576
# 185
# 94
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/shirt
#  TRAINING /home/ach/stilo/training/shirt
#  VALIDATION /home/ach/stilo/validation/shirt
#   5020
# training_length: 4267
# validation_length: 502
# testing_length: 251
# 4267
# 502
# 251
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/jeans
#  TRAINING /home/ach/stilo/training/jeans
#  VALIDATION /home/ach/stilo/validation/jeans
#   4747
# training_length: 4034
# validation_length: 474
# testing_length: 239
# 4034
# 474
# 239
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/bag
#  TRAINING /home/ach/stilo/training/bag
#  VALIDATION /home/ach/stilo/validation/bag
#   986
# training_length: 838
# validation_length: 98
# testing_length: 50
# 838
# 98
# 50
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/pants
#  TRAINING /home/ach/stilo/training/pants
#  VALIDATION /home/ach/stilo/validation/pants
#   7272
# training_length: 6181
# validation_length: 727
# testing_length: 364
# 6181
# 727
# 364
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/dress
#  TRAINING /home/ach/stilo/training/dress
#  VALIDATION /home/ach/stilo/validation/dress
#   14645
# training_length: 12448
# validation_length: 1464
# testing_length: 733
# 12448
# 1464
# 733
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/suit
#  TRAINING /home/ach/stilo/training/suit
#  VALIDATION /home/ach/stilo/validation/suit
#   5155
# training_length: 4381
# validation_length: 515
# testing_length: 259
# 4381
# 515
# 259
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/coat
#  TRAINING /home/ach/stilo/training/coat
#  VALIDATION /home/ach/stilo/validation/coat
#   295
# training_length: 250
# validation_length: 29
# testing_length: 16
# 250
# 29
# 16
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/t-shirt
#  TRAINING /home/ach/stilo/training/t-shirt
#  VALIDATION /home/ach/stilo/validation/t-shirt
#   15222
# training_length: 12938
# validation_length: 1522
# testing_length: 762
# 12938
# 1522
# 762
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/headwear
#  TRAINING /home/ach/stilo/training/headwear
#  VALIDATION /home/ach/stilo/validation/headwear
#   338
# training_length: 287
# validation_length: 33
# testing_length: 18
# 287
# 33
# 18
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/glasses
#  TRAINING /home/ach/stilo/training/glasses
#  VALIDATION /home/ach/stilo/validation/glasses
#   812
# training_length: 690
# validation_length: 81
# testing_length: 41
# 690
# 81
# 41
# Splitting
#
# Split Data
# SOURCE:  /data/stilo/catalog_full/jewelry
#  TRAINING /home/ach/stilo/training/jewelry
#  VALIDATION /home/ach/stilo/validation/jewelry
#   1885
# training_length: 1602
# validation_length: 188
# testing_length: 95
# 1602
# 188
# 95
# Splitting

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
try:
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo')
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo/training')
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo/validation')
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo/testing')
    
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo/training/skirt')
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo/training/jeans')
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo/training/dress')
    
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo/validation/skirt')
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo/validation/jeans')
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo/validation/dress')
    
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo/testing/skirt')
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo/testing/jeans')
    os.mkdir('/content/gdrive/My Drive/Colab Notebooks/data/stilo/testing/dress')

except OSError:
    pass
